# %% [markdown]
# [Accueil](../../index.ipynb) > [NSI Premiere](../index.ipynb)

# %% [markdown]
# # Représentation des données : les entiers relatifs
# Nous avons vu comment coder des **entiers positifs** en binaire, mais qu'en est-il des **entiers négatifs**?
#
# <div class="alert alert-info">
#     Dans la suite de ce cours nous allons utiliser des nombres codés sur 4 bits, la généralisation sur des nombres codés sur n bits sera alors triviale.</div>

# %% [markdown]
# ## Première approche : représentation en signe-valeur absolue
#
# Une première approche serait de coder les nombres entiers négatifs en utilisant le bit de poids fort pour déterminer le signe (0 pour + et 1 pour -), les bits restants pour la valeur absolue du nombre.
#
# **Le codage des nombres positifs reste inchangé par rapport aux entiers positifs dans cette représentation.**
#
# Cela donnerait
# <table>
#     <thead>
#     <tr>
#         <td>Nombre décimal</td>
#         <td>Nombre binaire</td>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#         <td>0</td>
#         <td>0000</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0001</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0010</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0011</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0100</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>0101</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>0110</td>
#     </tr>
#     <tr>
#         <td>7</td>
#         <td>0111</td>
#     </tr>
#     <tr>
#         <td>-0</td>
#         <td>1000</td>
#     </tr>
#     <tr>
#         <td>-1</td>
#         <td>1001</td>
#     </tr>
#     <tr>
#         <td>-2</td>
#         <td>1010</td>
#     </tr>
#     <tr>
#         <td>-3</td>
#         <td>1011</td>
#     </tr>
#     <tr>
#         <td>-4</td>
#         <td>1100</td>
#     </tr>
#     <tr>
#         <td>-5</td>
#         <td>1101</td>
#     </tr>
#     <tr>
#         <td>-6</td>
#         <td>1110</td>
#     </tr>
#     <tr>
#         <td>-7</td>
#         <td>1111</td>
#     </tr>
#     </tbody>
# </table>
#
# Cette convention a **deux problèmes**:
#
#  1. Le zéro est codé 2 fois;
#  2. L'addition n'est pas 'naturelle' pour un humain et l'implémenter demanderait des circuits électroniques complexes.
#
#  En effet 6+(-6)=0, or si on effectue l'addition naturellement on trouve :
#
#  <table>
#     <tr>
#         <td></td>
#         <td>(1)</td>
#         <td>(1)</td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>0</td>
#         <td>1</td>
#         <td>1</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>+</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>_</td>
#         <td>_</td>
#         <td>_</td>
#         <td>_</td>
#         <td>_</td>
#     </tr>
#     <tr>
#         <td>=</td>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
# </table>
#
# On trouve donc 4...
#
# **Pour ces raisons, le codage en signe-valeur absolue n'est pas utilisé pour les nombres entiers négatifs.**

# %% [markdown]
# ## Deuxième approche : représentation en complément à un
#
# Le bit de poids fort est utilisé pour le signe (0 pour +, 1 pour -)
#
# - Le codage des nombres positifs reste également inchangé dans cette représentation.
# - Pour les nombres négatifs:
#   - On code la valeur absolue en binaire;
#   - On inverse tous les bits (le bit de poids fort devient donc 1).
#
# Ainsi pour coder $-6_{10}$:
#
# - On code $+6_{10}=0110_2$:
# - On inverse tous les bits $0110_2 \to 1001_2$
#
# Voyons les resultats pour des nombres codés sur 4 bits
#
# <table>
#     <thead>
#     <tr>
#         <td>Nombre décimal</td>
#         <td>Nombre binaire</td>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#         <td>0</td>
#         <td>0000</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0001</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0010</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0011</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0100</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>0101</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>0110</td>
#     </tr>
#     <tr>
#         <td>7</td>
#         <td>0111</td>
#     </tr>
#     <tr>
#         <td>-7</td>
#         <td>1000</td>
#     </tr>
#     <tr>
#         <td>-6</td>
#         <td>1001</td>
#     </tr>
#     <tr>
#         <td>-5</td>
#         <td>1010</td>
#     </tr>
#     <tr>
#         <td>-4</td>
#         <td>1011</td>
#     </tr>
#     <tr>
#         <td>-3</td>
#         <td>1100</td>
#     </tr>
#     <tr>
#         <td>-2</td>
#         <td>1101</td>
#     </tr>
#     <tr>
#         <td>-1</td>
#         <td>1110</td>
#     </tr>
#     <tr>
#         <td>-0</td>
#         <td>1111</td>
#     </tr>
#     </tbody>
# </table>
#
# Pour cet algorithme de codage le 0 est également codé 2 fois.
#
# Essayons l'addition avec le même exemple $6+(-6)$:
#
#  <table>
#     <tr>
#         <td></td>
#         <td>0</td>
#         <td>1</td>
#         <td>1</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>+</td>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>_</td>
#         <td>_</td>
#         <td>_</td>
#         <td>_</td>
#         <td>_</td>
#     </tr>
#     <tr>
#         <td>=</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#         <td>1</td>
#     </tr>
# </table>
#
# On trouve bien que $1111_2=-0_{10}$
#
# Cet algorithme est parfois utilisé dans des microcontroleurs car il est facilement réalisable électroniquement. Cependant une égalité sur 0 nécessite deux tests.

# %% [markdown]
# ## Troisième approche : représentation en complément à deux
#
# La méthode du complément à deux est très proche de celle du complément à un, seule une étape supplémentaire est ajoutée à la fin de l'algorithme.
#
# - Le codage des nombres entiers reste inchangé (le bit de poids fort vaut 0)
# - Pour les nombres négatifs:
#   - On code la valeur absolue en binaire;
#   - On inverse tous les bits;
#   - On ajoute 1.
#
# Le tableau précédent est donc décalé de 1 pour les nombres négatifs.
# <table>
# <tr>
#     <td>
#         <table>
#             <thead>
#             <tr>
#                 <td>Nombre décimal</td>
#                 <td>Nombre binaire</td>
#             </tr>
#             </thead>
#             <tbody>
#             <tr>
#                 <td>-8</td>
#                 <td>1000</td>
#             </tr>
#             <tr>
#                 <td>-7</td>
#                 <td>1001</td>
#             </tr>
#             <tr>
#                 <td>-6</td>
#                 <td>1010</td>
#             </tr>
#             <tr>
#                 <td>-5</td>
#                 <td>1011</td>
#             </tr>
#             <tr>
#                 <td>-4</td>
#                 <td>1100</td>
#             </tr>
#             <tr>
#                 <td>-3</td>
#                 <td>1101</td>
#             </tr>
#             <tr>
#                 <td>-2</td>
#                 <td>1110</td>
#             </tr>
#             <tr>
#                 <td>-1</td>
#                 <td>1111</td>
#             </tr>
#             </tbody>
#         </table>
#     </td>
#     <td>
#         <table>
#             <thead>
#             <tr>
#                 <td>Nombre décimal</td>
#                 <td>Nombre binaire</td>
#             </tr>
#             </thead>
#             <tbody>
#             <tr>
#                 <td>0</td>
#                 <td>0000</td>
#             </tr>
#             <tr>
#                 <td>1</td>
#                 <td>0001</td>
#             </tr>
#             <tr>
#                 <td>2</td>
#                 <td>0010</td>
#             </tr>
#             <tr>
#                 <td>3</td>
#                 <td>0011</td>
#             </tr>
#             <tr>
#                 <td>4</td>
#                 <td>0100</td>
#             </tr>
#             <tr>
#                 <td>5</td>
#                 <td>0101</td>
#             </tr>
#             <tr>
#                 <td>6</td>
#                 <td>0110</td>
#             </tr>
#             <tr>
#                 <td>7</td>
#                 <td>0111</td>
#             </tr>
#             </tbody>
#         </table>
#     </td>
# </tr>
# </table>
#
#
#
#
#
# **Remarques**
#
# - Le 0 est codé une seule fois;
# - Sur un octet on peut coder les nombres de -128 à +127.
#
# <div class="alert alert-info"><b>La méthode du complément à deux est l'algorithme le plus utilisé pour la représentation des nombres entiers relatifs.</b></div>

# %% [markdown]
# ### Généralisation sur k bits
#
# - Sur k bits on peut coder les nombres $\{-2^{k-1},....,2^{k-1}-1\}$
# - Le complément à deux d'un entier n est obtenu par le calcul $2^k-\lvert n \rvert$
# - Le complément à deux du complément à deux d'un entier n est n : $2^k-(2^k-n) = n$ (l'opposé de l'opposé est bien le nombre.)
# - Le nom complet de cette opération est "complément à $2^k$"

# %% [markdown]
# ### Conversion de décimal à binaire
#
# **Exemple**
#
# Coder -36 en complément à deux sur un octet.
#
# #### Première méthode : utilisation de la formule arithmétique $2^k-\lvert n \rvert$
#
# Arithmétiquement, coder le nombre $n_{10}<0$ en complément à deux revient à coder le nombre $2^k-\lvert n_{10} \rvert$ où k est le nombre de bits utilisés pour l'encodage.
#
#
# On code donc le nombre $2^8-36=256-36=220_{10}=11011100_2$ (voir le codage binaire d'un entier décimal)
#
# #### Deuxième méthode : Codage en suivant l'algorithme pas à pas
#
# <table>
#     <thead>
#         <tr><td></td><td>Nombre décimal</td><td>Binaire</td></tr>
#     </thead>
#     <tbody>
#         <tr><td>Valeur absolue du nombre</td><td>36</td><td>$00100100_2$</td></tr>
#         <tr><td>Complément à 1</td><td>255-36=219</td><td>$11011011_2$</td></tr>
#         <tr><td>Complément à 2</td><td>219+1=220</td><td>$11011100_2$</td></tr>
#     </tbody>
# </table>
#
# #### Troisième méthode :
#
# - Garder tous les 0 de droite jusqu'au premier 1, ainsi que ce 1
# - Inverser tout le reste
#
# **A faire**
#
# Coder -65 en complément à deux sur un octet en utilisant toutes ces méthodes.

# %% [markdown]
# ### Conversion de binaire à décimal
#
# **Exemple**
#
# Coder $11011100_2$ en décimal (c'est un nombre entier négatif)
#
# #### Première méthode : utilisation de la formule arithmétique
#
# - Si le bit de poids fort est 1, il s'agit donc d'un nombre négatif
#   - On convertit le nombre en décimal : $11011100_2=220_{10}$
#   - Le nombre en complément à 2 est donc $2^8-220=256-220=30$
#   - Le nombre est donc -30.
# - Si le bit de poids fort est 0, il s'agit donc d'un nombre positif
#   - On décode 'normalement'
#
# #### Deuxième méthode : Codage en remontant l'algorithme pas à pas
#
# Remonter l'algorithme pour un nombre négatif serait:
#
# - Soustraire 1 : $11011100_2 \to 11011011_2$
# - Inverser les bits : $11011011_2 \to 00100100_2$
# - Convertir en décimal : $00100100_2 \to 36_{10}$
# - Trouver l'opposé  : $36_{10} \to -36_{10}$
#
# Mais une méthode plus facile revient à faire:
#
# - Inverser les bits : $11011100_2 \to 00100011_2$
# - Ajouter 1 : $00100011_2 \to 00100100_2$
# - Convertir en décimal : $00100100_2 \to 36_{10}$
# - Trouver l'opposé : $36_{10} \to -36_{10}$
#
# **A faire**
#
# - Exercice 1 : Coder $11000001_2$ en décimal.
# - Exercice 2 : Coder $-111_{10}$ en binaire sur un octet.
# - Exercice 3 : $a=10101010_2$ et $b=01101101$. Calculer a+b en décimal, retrouver ce résultat convertissant a et b en décimal.

# %% [markdown]
# ### Addition et dépassement de capacité (cas positifs)
#
# Dans les exemples qui suivent nous allons prendre le cas d'entiers positifs signés sur 1 octet.
#
# - Effectuons l'addition de 65 et 33
#
# <table>
#     <thead>
#         <tr>
#             <td></td>
#             <td>Signe</td>
#             <td>64</td>
#             <td>32</td>
#             <td>16</td>
#             <td>8</td>
#             <td>4</td>
#             <td>2</td>
#             <td>1</td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>+65</td>
#             <td>0</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <td>+33</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <td>(+65)+(+33)=+98</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#             <td>0</td>
#         </tr>
#     </tbody>
# </table>
# Dans cette opération tout se passe bien. Il n'y a pas eu de dépassement de capacité de calcul.
#
#
# - Effectuons l'addition de 65 et 66
#
# <table>
#     <thead>
#         <tr>
#             <td></td>
#             <td>Signe</td>
#             <td>64</td>
#             <td>32</td>
#             <td>16</td>
#             <td>8</td>
#             <td>4</td>
#             <td>2</td>
#             <td>1</td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>+65</td>
#             <td>0</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <td>+66</td>
#             <td>0</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <td>(+65)+(+66)=+131</td>
#             <td><b style="color:red">1</b></td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#         </tr>
#     </tbody>
# </table>
#
# Il y  a visiblement un problème puisque le résultat donne un nombre négatif.
#
# Ce qui est normal puisque sur un octet le plus grand nombre codable est +127
#
# <div class="alert alert-info">Lorsqu'on additionne deux nombres positifs signés, il y a dépassement de capacité si le bit de signe change de valeur.</div>
#
# [Exemple de conséquence d'un dépassement de capacité](https://www.youtube.com/watch?v=gp_D8r-2hwk)

# %% [markdown]
# ### Addition et dépassement de capacité (cas négatifs)
#
# Nous avons déjà codé les nombres:
#  - -65 en binaire et cela donne $10111111_2$
#  - -36 en binaire et cela donne $11011100_2$
#
# - Effectuons l'opération (-65) + (-36)
#
#
# <table>
#     <thead>
#         <tr>
#             <td></td>
#             <td>Retenue</td>
#             <td>Signe</td>
#             <td>64</td>
#             <td>32</td>
#             <td>16</td>
#             <td>8</td>
#             <td>4</td>
#             <td>2</td>
#             <td>1</td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>-65</td>
#             <td></td>
#             <td>1</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <td>-36</td>
#             <td></td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#         </tr>
#         <tr>
#             <td>(-65)+(-36)=-101</td>
#             <td>+1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#         </tr>
#     </tbody>
# </table>
#
# Ici l'addition des deux nombres donne le bon résultat car on ne tient pas compte du dernier dépassement.
#
# - Effectuons maintenant l'opération (-65) + (-65)
#
#
# <table>
#     <thead>
#         <tr>
#             <td></td>
#             <td>Retenue</td>
#             <td>Signe</td>
#             <td>64</td>
#             <td>32</td>
#             <td>16</td>
#             <td>8</td>
#             <td>4</td>
#             <td>2</td>
#             <td>1</td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>-65</td>
#             <td></td>
#             <td>1</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <td>-65</td>
#             <td></td>
#             <td>1</td>
#             <td>0</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#         </tr>
#         <tr>
#             <td>(-65)+(-65)=-130</td>
#             <td>+1</td>
#             <td><b style="color:red">0</b></td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>1</td>
#             <td>0</td>
#         </tr>
#     </tbody>
# </table>
#
# <div class="alert alert-info">Lorsqu'on additionne deux nombres négatifs signés, il y a dépassement de capacité si le bit de signe change de valeur.</div>

# %% [markdown]
# ## Estimation du nombre de bits pour coder un nombre
#
# Nous savons déjà que si nous diposons de k bits on peut coder :
#
# - pour les nombre entiers positifs les nombres de 0 à $2^k-1$. Exemple si k=8 on peut coder de 0 à 256-1=255.
# - pour les nombre entiers relatifs les nombres de $-2^{k-1}$ à $2^{k-1}-1$. Exemple si k=8 on peut coder de -128 à +127.
#
# Maintenant posons nous la question inverse : Etant donné un nombre *n*, quel est le nombre de bits *k* nécessaire pour le coder ?
#
#
# ### Première méthode : en tatonnant
#
# **Exemple** : Combien de bits faut-il pour coder $1000000$ au format des entiers naturels ?
#
# - prenons k=10, on obtient $2^{10}-1=1023$
# - prenons k=15, on obtient $2^{15}-1=32767$
# - prenons k=20, on obtient $2^{20}-1=1048575$
# - prenons k=19, on obtient $2^{19}-1=524287$
#
# Il faut donc 20 bits pour coder le nombre 1 million.
#
# **Excercice** combien de bits pour coder 1 milliard au format des entiers naturels?
#
# ### Deuxième méthode : avec le logarithme
#
# **La fonction logarithme en base 2 peut être vue comme la fonction qui renvoie la puissance de 2 d'un nombre *n* que l'on écrirait sous la forme $n=2^k$**
#
# **Exemples :**
#
#
# - $\log_{2}(4)=\log_{2}(2^2) = 2$
# - $\log_{2}(256)=\log_{2}(2^8) = 8$
# - $\log_{2}(\frac{1}{8})=\log_{2}(2^{-3}) = -3$
#
# Ainsi, pour répondre à la question précédente :
#
# On cherche k tel que $1000000 = 2^k -1\Leftrightarrow 1000000 +1 = 2^k  \Leftrightarrow k = \log_{2}(1000001) \Leftrightarrow k \approx 19.93$
#
# Il faut donc bien 20 bits pour coder le nombre 1 million.
#
#
# **Excercice** combien de bits pour coder -36000 au format des entiers relatifs?
