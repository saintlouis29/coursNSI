# %% [markdown]
# [Retour au sommaire](../index.ipynb)

# %% [markdown]
# # 6.2 Architecture matérielle et OS : réseau

# %% [markdown]
# [Retour au sommaire](../index.ipynb)
