# %% [markdown]
# TP CSV
# ===

# %%
import csv
from IPython.display import HTML, display
from operator import itemgetter, attrgetter

def import_csv2(filename, types=None):
    """
    ouvre un fichier et retourne une liste de dictionnaires
    on peut préciser les types pour chaque colonne exemple types=['str','int','float','str'],
    dans ce cas le contenu est casté (changement de type)
    """
    with open(filename, newline='', encoding='utf8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter=',')
        # Si on a précise les types
        if types != None:
            result=[]
            for row in reader:
                keys = [k for k in row.keys()]
                values = [v for v in row.values()]
                updates = {}
                for i in range(len(types)):
                    if types[i]=='int':
                        updates[keys[i]]=int(values[i])
                    elif types[i]=='float':
                        updates[keys[i]]=float(values[i])
                row.update(updates)
                result.append(row)
            return result
        # Si on n'a pas précisé de type
        else:
            return list(reader)
        
def filter_colums(datas, list_of_column_names, action='keep'):
    """
    Retourne les données filtrées par colonne
    list_of_column_names : la liste des colonnes
    action : defaut = 'keep' sinon 'remove'
    """
    if datas:
        result=[]
        # récupérons les clés
        keys=[k for k in datas[0].keys()]
        for row in datas:
            new_row = row.copy()
            result.append(new_row)
            for k in keys:
                if action=='remove':
                    if k in list_of_column_names:
                        new_row.pop(k)
                else:
                    if k not in list_of_column_names:
                        new_row.pop(k)
        return result
    return datas

def filter_lines(datas, key, value, operator = '='):
    """
    Filtre les lignes dont la valeur de la clé vaut 'value'
    Les opérateurs peuvent être 'in', '<', '>' par défaut =
    """
    if operator == 'in':
         return [row for row in datas if value.lower() in row[key].lower()]
    elif operator == '>':
        if isinstance(datas[0][key], str):
            return [row for row in datas if row[key].lower() > value.lower()]
        else:
            return [row for row in datas if row[key] > value]
    elif operator == '<':
        if isinstance(datas[0][key], str):
            return [row for row in datas if row[key].lower() < value.lower()]
        else:
            return [row for row in datas if row[key] < value]
    else:
        if isinstance(datas[0][key], int):
            return [row for row in datas if row[key] == int(value)]
        elif isinstance(datas[0][key], float):
            return [row for row in datas if row[key] == float(value)]
        else:
            return [row for row in datas if row[key].lower() == value.lower()]

def display_table(datas):
    """
    Retourne le tableau sous forme de tableau html
    """
    if datas:
        display(HTML(
           '<table><thead><tr><th>{}</th></tr></thead><tbody><tr>{}</tr></tbody></table>'.format(
               '</th><th>'.join([k.title() for k in datas[0].keys()]),
               '</tr><tr>'.join(
                   '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row.values())) for row in datas)
               )
        ))
    else:
       display(HTML('Rien a afficher'))

# %% [markdown]
# Importation des données depuis le fichier 'datas.csv'
# ---

# %%
from os import path
if not path.exists('datas.csv'):
    import zipfile
    with zipfile.ZipFile('datas.zip', 'r') as zip_ref:
        zip_ref.extractall('.')    

dicos = import_csv2('datas.csv', types=['str','str','str','str','int'])

# %% [markdown]
# Tous les titres de Madonna entre 2000 et 2008. Colonnes affichées Titre, artiste, année.
# ---

# %%
f = filter_lines(dicos, 'artist_name', 'madonna')
f = filter_lines(f, 'year', 2000, operator = '>')
f = filter_lines(f, 'year', 2008, operator = '<')
f = filter_colums(f, ['song_id','release'], action='remove')
# Les trier par année puis par titre

# %%
f = sorted(f, key=itemgetter('year','title'))
display_table(f)
# Out:
# <table><thead><tr><th>Title</th><th>Artist_Name</th><th>Year</th></tr></thead><tbody><tr><td>American Life [Headcleanr Rock Mix]</td><td>Madonna</td><td>2003</td></tr><tr><td>Easy Ride (Album Version)</td><td>Madonna</td><td>2003</td></tr><tr><td>Hollywood (Album Version)</td><td>Madonna</td><td>2003</td></tr><tr><td>I'm So Stupid (Album Version)</td><td>Madonna</td><td>2003</td></tr><tr><td>Intervention (Album Version)</td><td>Madonna</td><td>2003</td></tr><tr><td>Into The Hollywood Groove [featuring Missy Elliott] [The Passengerz Mix]</td><td>Madonna</td><td>2003</td></tr><tr><td>Love Profusion (Album Version)</td><td>Madonna</td><td>2003</td></tr><tr><td>Nobody Knows Me [Mount Sims Old School Mix]</td><td>Madonna</td><td>2003</td></tr><tr><td>Nothing Fails (Album Version)</td><td>Madonna</td><td>2003</td></tr><tr><td>Nothing Fails [Nevins Mix]</td><td>Madonna</td><td>2003</td></tr><tr><td>Forbidden Love (Album Version)</td><td>Madonna</td><td>2005</td></tr><tr><td>Hung Up (Album Version)</td><td>Madonna</td><td>2005</td></tr><tr><td>Hung Up (SDP Extended Vocal)</td><td>Madonna</td><td>2005</td></tr><tr><td>Hung Up (Tracy Young's Get Up And Dance Groove Edit)</td><td>Madonna</td><td>2005</td></tr><tr><td>Like It Or Not (Album Version)</td><td>Madonna</td><td>2005</td></tr><tr><td>Push (Album Version)</td><td>Madonna</td><td>2005</td></tr><tr><td>Die Another Day [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Get Together (Danny Howells & Dick Trevor KinkyFunk Mix)</td><td>Madonna</td><td>2006</td></tr><tr><td>Get Together (Jacques Lu Cont Mix)</td><td>Madonna</td><td>2006</td></tr><tr><td>Get Together (Tiefschwarz Remix)</td><td>Madonna</td><td>2006</td></tr><tr><td>History (Non-Album Track)</td><td>Madonna</td><td>2006</td></tr><tr><td>Holiday [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Hollywood [Remix] [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>I Love New York [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Jump [Extended Album Version]</td><td>Madonna</td><td>2006</td></tr><tr><td>Jump [Jacques Lu Cont Edit]</td><td>Madonna</td><td>2006</td></tr><tr><td>Lament [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Let It Will Be (Paper Faces Mix)</td><td>Madonna</td><td>2006</td></tr><tr><td>Mother And Father [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Nobody Knows Me [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Sorry (Album Version)</td><td>Madonna</td><td>2006</td></tr><tr><td>Sorry (Green Velvet Remix Edit)</td><td>Madonna</td><td>2006</td></tr><tr><td>Sorry (Man With Guitar Mix)</td><td>Madonna</td><td>2006</td></tr><tr><td>Sorry (Paul Oakenfold Remix)</td><td>Madonna</td><td>2006</td></tr><tr><td>Sorry (Single Edit)</td><td>Madonna</td><td>2006</td></tr><tr><td>The Beast Within [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Vogue [Live]</td><td>Madonna</td><td>2006</td></tr><tr><td>Confessions [Live]</td><td>Madonna</td><td>2007</td></tr><tr><td>Get Together [Live] [Bonus Track]</td><td>Madonna</td><td>2007</td></tr><tr><td>Isaac [Live]</td><td>Madonna</td><td>2007</td></tr><tr><td>Lucky Star [Live]</td><td>Madonna</td><td>2007</td></tr><tr><td>Sorry [Live]</td><td>Madonna</td><td>2007</td></tr></tbody></table>

# %% [markdown]
# Trouver tous les morceaux de l'artiste 'Tricky' de l'album 'blowback'.
# ---

# %%
f = filter_lines(dicos, 'artist_name', 'tricky')
f = filter_lines(f, 'release', 'blowback')
display_table(f)
# Out:
# <table><thead><tr><th>Song_Id</th><th>Title</th><th>Release</th><th>Artist_Name</th><th>Year</th></tr></thead><tbody><tr><td>SOGJNGD12A8C1384E2</td><td>A Song for Yukiko (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOGVTEZ12A8C1384C3</td><td>Bury the Evidence (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOFHDUX12A8C1384E9</td><td>The Hawkman Is Coming (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOSEJLE12A8C13AFA3</td><td>Excess (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOHHDAW12A8C1384BA</td><td>Your Name (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOZKPKS12A8AE488A3</td><td>Something in the Way (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOEDOHT12A8C13A2D1</td><td>Evolution Revolution Love (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOYITYB12A8C1384ED</td><td>Evolution Revolution Love Remix (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOCVFOB12A8C1384D8</td><td>Give It to 'Em (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOJYVLV12A8C13A2E5</td><td>Girls (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOSBQOI12A8C1384BF</td><td>Diss Never (Dig Up We History) (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOSQWVF12A8C13A2D6</td><td>Over Me (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOYXXRJ12A8C1384D2</td><td>Five Days (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr><tr><td>SOOHIJO12A8C13A2E9</td><td>You Don't Wanna (Album version)</td><td>Blowback</td><td>Tricky</td><td>2001</td></tr></tbody></table>

# %% [markdown]
# Trouver tous les morceaux dont les artistes commencent par 'ab' et dont l'année est > à 2000
# ---

# %%
f = filter_lines(dicos, 'artist_name', 'ab', operator='>')
f = filter_lines(f, 'artist_name', 'ac', operator='<')
f = filter_lines(f, 'year', 2005, operator = '>')
display_table(f)
# Out:
tr><td>SOFFGOR12AF72A34E5</td><td>Blacken The Sky</td><td>From Ashes</td><td>Abysmal Dawn</td><td>2006</td></tr><tr><td>SOQBZRL12A8AE4746B</td><td>I'll Love You So</td><td>When You Love Someone (Songs Of Love & Friendship)</td><td>Above The Golden State</td><td>2008</td></tr><tr><td>SOMIOMP12A58A77E8E</td><td>Brand New Moses</td><td>Voices</td><td>Able Baker Fox</td><td>2008</td></tr><tr><td>SOFVPDA12A58A7AE6C</td><td>I35</td><td>Strychnine.213</td><td>Aborted</td><td>2008</td></tr><tr><td>SOQOKQV12AB01856FA</td><td>La Vigilia</td><td>La Educación</td><td>Abraham Boba</td><td>2009</td></tr><tr><td>SOTBEPX12A8C136D24</td><td>Dead City / Waste Wilderness</td><td>Skeleton</td><td>Abe Vigoda</td><td>2008</td></tr><tr><td>SOHPIWI12A8C13E73E</td><td>You</td><td>On The Way</td><td>Abra Moore</td><td>2007</td></tr><tr><td>SORPOLP12A8AE47369</td><td>Ophiolatry On A Hemocite Platter</td><td>Strychnine.213</td><td>Aborted</td><td>2008</td></tr><tr><td>SOGVACF12AB0182BF5</td><td>Pidän maastanne</td><td>Iiris</td><td>Absoluuttinen nollapiste</td><td>2007</td></tr><tr><td>SOBSAWB12A8C13E730</td><td>I Believe</td>< ...

# %% [markdown]
# les trier par nom d'artiste dans l'ordre descendant.

# %%
f=sorted(f, key=itemgetter('artist_name'), reverse=True)
display_table(f)
# Out:
# <table><thead><tr><th>Song_Id</th><th>Title</th><th>Release</th><th>Artist_Name</th><th>Year</th></tr></thead><tbody><tr><td>SOZEFGL12A8AE46F74</td><td>Grotesque Modern Art</td><td>Programmed to Consume</td><td>Abysmal Dawn</td><td>2008</td></tr><tr><td>SOADXIK12A8C13868F</td><td>Impending Doom (Instrumental)</td><td>From Ashes</td><td>Abysmal Dawn</td><td>2006</td></tr><tr><td>SOWREYM12A58A7B484</td><td>The Descent</td><td>Programmed to Consume</td><td>Abysmal Dawn</td><td>2008</td></tr><tr><td>SOFFGOR12AF72A34E5</td><td>Blacken The Sky</td><td>From Ashes</td><td>Abysmal Dawn</td><td>2006</td></tr><tr><td>SOVDERV12A8AE471C2</td><td>Twilight's Fallen</td><td>Programmed to Consume</td><td>Abysmal Dawn</td><td>2008</td></tr><tr><td>SOIBAES12A8C1386A9</td><td>State Of Mind</td><td>From Ashes</td><td>Abysmal Dawn</td><td>2006</td></tr><tr><td>SOLDIPI12A8AE46F76</td><td>A Remission of Life</td><td>Programmed to Consume</td><td>Abysmal Dawn</td><td>2008</td></tr><tr><td>SOHPYEI12AF72A24FF</td><td>In The Hands Of Death</td><td>From Ashes</td><td>Abysmal Dawn</td><td>2006</td></tr><tr><td>SODRVWF12A58A7DB20</td><td>Programmed to Consume</td><td>Programmed to Consume</td><td>Abysmal Dawn</td><td>2008</td></tr><tr><td>SOORFPO12A8C1386A0</td><td>Servants To Their Knees</td><td>From Ashes</td><td>Abysmal Dawn</td><td>2006</td></tr><tr><td>SOMTZYN12A8AE471C0</td><td